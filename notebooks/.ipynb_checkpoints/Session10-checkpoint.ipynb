# %% [markdown]
# # Autoecoders
# Notebook adapted and inspired from: https://github.com/ageron/handson-ml2/blob/master/17_autoencoders_and_gans.ipynb

# %%
# some imports
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))

# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"


# TensorFlow ≥2.0 is required
import tensorflow as tf
from tensorflow import keras

assert tf.__version__ >= "2.0"


# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)
plt.rc('font', size=12) 
plt.rc('figure', figsize = (12, 5))

# Settings for the visualizations
#import seaborn as sns
#sns.set_style("whitegrid")
#sns.set_context("notebook", font_scale=1, rc={"lines.linewidth": 2,'font.family': [u'times']})

import pandas as pd
pd.set_option('display.max_rows', 25)
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_colwidth', 50)

# Ignore useless warnings (see SciPy issue #5998)
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")


def plot_image(image):
    plt.imshow(image, cmap="binary")
    plt.axis("off")
# Out:
# /var/folders/4c/yxd8svq13sj393bkl75mt6km0000gn/T/ipykernel_2470/48045301.py:2: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>
# 2023-12-18 12:09:44.303135: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Stacked Autoencoder

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train_full = X_train_full.astype(np.float32) / 255
X_test = X_test.astype(np.float32) / 255
X_train, X_valid = X_train_full[:-5000], X_train_full[-5000:]
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 7s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 1s 0us/step

# %%
def rounded_accuracy(y_true, y_pred):
    return keras.metrics.binary_accuracy(tf.round(y_true), tf.round(y_pred))

# %%
tf.random.set_seed(42)
np.random.seed(42)

stacked_encoder = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dense(100, activation="selu"),
    keras.layers.Dense(30, activation="selu"),
])
stacked_decoder = keras.models.Sequential([
    keras.layers.Dense(100, activation="selu", input_shape=[30]),
    keras.layers.Dense(28 * 28, activation="sigmoid"),
    keras.layers.Reshape([28, 28])
])
stacked_ae = keras.models.Sequential([stacked_encoder, stacked_decoder])
stacked_ae.compile(loss="binary_crossentropy",
                   optimizer=keras.optimizers.SGD(lr=1.5), metrics=[rounded_accuracy])
history = stacked_ae.fit(X_train, X_train, epochs=20,
                         validation_data=(X_valid, X_valid))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/20
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.6601 - rounded_accuracy: 0.5991 - val_loss: 0.5972 - val_rounded_accuracy: 0.6891
# Epoch 2/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.5370 - rounded_accuracy: 0.7274 - val_loss: 0.5057 - val_rounded_accuracy: 0.7444
# Epoch 3/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4927 - rounded_accuracy: 0.7512 - val_loss: 0.4857 - val_rounded_accuracy: 0.7579
# Epoch 4/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4723 - rounded_accuracy: 0.7719 - val_loss: 0.4626 - val_rounded_accuracy: 0.7819
# Epoch 5/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4472 - rounded_accuracy: 0.7932 - val_loss: 0.4377 - val_rounded_accuracy: 0.7991
# Epoch 6/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4255 - rounded_accuracy: 0.8071 - val_loss: 0.4194 - val_rounded_accuracy: 0.8115
# Epoch 7/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4096 - rounded_accuracy: 0.8187 - val_loss: 0.4054 - val_rounded_accuracy: 0.8231
# Epoch 8/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3971 - rounded_accuracy: 0.8290 - val_loss: 0.3945 - val_rounded_accuracy: 0.8329
# Epoch 9/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3877 - rounded_accuracy: 0.8380 - val_loss: 0.3865 - val_rounded_accuracy: 0.8407
# Epoch 10/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3811 - rounded_accuracy: 0.8447 - val_loss: 0.3810 - val_rounded_accuracy: 0.8461
# Epoch 11/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3765 - rounded_accuracy: 0.8493 - val_loss: 0.3772 - val_rounded_accuracy: 0.8502
# Epoch 12/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3731 - rounded_accuracy: 0.8530 - val_loss: 0.3743 - val_rounded_accuracy: 0.8534
# Epoch 13/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3704 - rounded_accuracy: 0.8560 - val_loss: 0.3718 - val_rounded_accuracy: 0.8564
# Epoch 14/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3681 - rounded_accuracy: 0.8587 - val_loss: 0.3696 - val_rounded_accuracy: 0.8588
# Epoch 15/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3660 - rounded_accuracy: 0.8612 - val_loss: 0.3676 - val_rounded_accuracy: 0.8613
# Epoch 16/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3640 - rounded_accuracy: 0.8636 - val_loss: 0.3656 - val_rounded_accuracy: 0.8635
# Epoch 17/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3621 - rounded_accuracy: 0.8658 - val_loss: 0.3637 - val_rounded_accuracy: 0.8657
# Epoch 18/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3601 - rounded_accuracy: 0.8680 - val_loss: 0.3617 - val_rounded_accuracy: 0.8678
# Epoch 19/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3582 - rounded_accuracy: 0.8701 - val_loss: 0.3598 - val_rounded_accuracy: 0.8699
# Epoch 20/20
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3563 - rounded_accuracy: 0.8721 - val_loss: 0.3579 - val_rounded_accuracy: 0.8718

# %%
def show_reconstructions(model, images=X_valid, n_images=5):
    reconstructions = model.predict(images[:n_images])
    fig = plt.figure(figsize=(n_images * 1.5, 3))
    for image_index in range(n_images):
        plt.subplot(2, n_images, 1 + image_index)
        plot_image(images[image_index])
        plt.subplot(2, n_images, 1 + n_images + image_index)
        plot_image(reconstructions[image_index])

# %%
show_reconstructions(stacked_ae)
# Out:
# 1/1 [==============================] - 0s 60ms/step

# %%
## Visualizing Fashion MNIST

# %%
np.random.seed(42)

from sklearn.manifold import TSNE

X_valid_compressed = stacked_encoder.predict(X_valid)
tsne = TSNE()
X_valid_2D = tsne.fit_transform(X_valid_compressed)
X_valid_2D = (X_valid_2D - X_valid_2D.min()) / (X_valid_2D.max() - X_valid_2D.min())
# Out:
# 157/157 [==============================] - 0s 1ms/step

# %%
plt.scatter(X_valid_2D[:, 0], X_valid_2D[:, 1], c=y_valid, s=10, cmap="tab10")
plt.axis("off")
plt.show()

# %%
# adapted from https://scikit-learn.org/stable/auto_examples/manifold/plot_lle_digits.html
plt.figure(figsize=(10, 8))
cmap = plt.cm.tab10
plt.scatter(X_valid_2D[:, 0], X_valid_2D[:, 1], c=y_valid, s=10, cmap=cmap)
image_positions = np.array([[1., 1.]])
for index, position in enumerate(X_valid_2D):
    dist = np.sum((position - image_positions) ** 2, axis=1)
    if np.min(dist) > 0.02: # if far enough from other images
        image_positions = np.r_[image_positions, [position]]
        imagebox = mpl.offsetbox.AnnotationBbox(
            mpl.offsetbox.OffsetImage(X_valid[index], cmap="binary"),
            position, bboxprops={"edgecolor": cmap(y_valid[index]), "lw": 2})
        plt.gca().add_artist(imagebox)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Using Convolutional Layers Instead of Dense Layers
#
# Let's build a stacked Autoencoder with 3 hidden layers and 1 output layer (i.e., 2 stacked Autoencoders).

# %%
tf.random.set_seed(42)
np.random.seed(42)

conv_encoder = keras.models.Sequential([
    keras.layers.Reshape([28, 28, 1], input_shape=[28, 28]),
    keras.layers.Conv2D(16, kernel_size=3, padding="SAME", activation="selu"),
    keras.layers.MaxPool2D(pool_size=2),
    keras.layers.Conv2D(32, kernel_size=3, padding="SAME", activation="selu"),
    keras.layers.MaxPool2D(pool_size=2),
    keras.layers.Conv2D(64, kernel_size=3, padding="SAME", activation="selu"),
    keras.layers.MaxPool2D(pool_size=2)
])
conv_decoder = keras.models.Sequential([
    keras.layers.Conv2DTranspose(32, kernel_size=3, strides=2, padding="VALID", activation="selu",
                                 input_shape=[3, 3, 64]),
    keras.layers.Conv2DTranspose(16, kernel_size=3, strides=2, padding="SAME", activation="selu"),
    keras.layers.Conv2DTranspose(1, kernel_size=3, strides=2, padding="SAME", activation="sigmoid"),
    keras.layers.Reshape([28, 28])
])
conv_ae = keras.models.Sequential([conv_encoder, conv_decoder])

conv_ae.compile(loss="binary_crossentropy", optimizer=keras.optimizers.SGD(lr=1.0),
                metrics=[rounded_accuracy])
history = conv_ae.fit(X_train, X_train, epochs=5,
                      validation_data=(X_valid, X_valid))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/5
# 1719/1719 [==============================] - 18s 10ms/step - loss: 0.5939 - rounded_accuracy: 0.6891 - val_loss: 0.5248 - val_rounded_accuracy: 0.7307
# Epoch 2/5
# 1719/1719 [==============================] - 20s 11ms/step - loss: 0.4165 - rounded_accuracy: 0.8420 - val_loss: 0.3768 - val_rounded_accuracy: 0.8722
# Epoch 3/5
# 1719/1719 [==============================] - 18s 10ms/step - loss: 0.3639 - rounded_accuracy: 0.8753 - val_loss: 0.3565 - val_rounded_accuracy: 0.8781
# Epoch 4/5
# 1719/1719 [==============================] - 18s 10ms/step - loss: 0.3483 - rounded_accuracy: 0.8819 - val_loss: 0.3442 - val_rounded_accuracy: 0.8854
# Epoch 5/5
# 1719/1719 [==============================] - 18s 10ms/step - loss: 0.3376 - rounded_accuracy: 0.8899 - val_loss: 0.3349 - val_rounded_accuracy: 0.8937

# %%
conv_encoder.summary()
conv_decoder.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_1 (Reshape)         (None, 28, 28, 1)         0
#
#  conv2d (Conv2D)             (None, 28, 28, 16)        160
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 32)          0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 3, 3, 64)          0
#  g2D)
#
# =================================================================
# Total params: 23296 (91.00 KB)
# Trainable params: 23296 (91.00 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_transpose (Conv2DTr  (None, 7, 7, 32)          18464
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 14, 14, 16)        4624
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 1)         145
#  Transpose)
#
#  reshape_2 (Reshape)         (None, 28, 28)            0
#
# =================================================================
# Total params: 23233 (90.75 KB)
# Trainable params: 23233 (90.75 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
show_reconstructions(conv_ae)
plt.show()
# Out:
# 1/1 [==============================] - 0s 83ms/step

# %% [markdown]
# ## Stacked denoising Autoencoder
# Using Gaussian noise:

# %%
tf.random.set_seed(42)
np.random.seed(42)

denoising_encoder = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.GaussianNoise(0.2),
    keras.layers.Dense(100, activation="selu"),
    keras.layers.Dense(30, activation="selu")
])
denoising_decoder = keras.models.Sequential([
    keras.layers.Dense(100, activation="selu", input_shape=[30]),
    keras.layers.Dense(28 * 28, activation="sigmoid"),
    keras.layers.Reshape([28, 28])
])
denoising_ae = keras.models.Sequential([denoising_encoder, denoising_decoder])
denoising_ae.compile(loss="binary_crossentropy", optimizer=keras.optimizers.SGD(lr=1.0),
                     metrics=[rounded_accuracy])
history = denoising_ae.fit(X_train, X_train, epochs=10,
                           validation_data=(X_valid, X_valid))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.6615 - rounded_accuracy: 0.5955 - val_loss: 0.5924 - val_rounded_accuracy: 0.6942
# Epoch 2/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.5354 - rounded_accuracy: 0.7233 - val_loss: 0.5074 - val_rounded_accuracy: 0.7367
# Epoch 3/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4994 - rounded_accuracy: 0.7423 - val_loss: 0.4957 - val_rounded_accuracy: 0.7454
# Epoch 4/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4895 - rounded_accuracy: 0.7525 - val_loss: 0.4857 - val_rounded_accuracy: 0.7587
# Epoch 5/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4771 - rounded_accuracy: 0.7678 - val_loss: 0.4700 - val_rounded_accuracy: 0.7753
# Epoch 6/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4576 - rounded_accuracy: 0.7861 - val_loss: 0.4465 - val_rounded_accuracy: 0.7952
# Epoch 7/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4328 - rounded_accuracy: 0.8058 - val_loss: 0.4218 - val_rounded_accuracy: 0.8151
# Epoch 8/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.4109 - rounded_accuracy: 0.8231 - val_loss: 0.4031 - val_rounded_accuracy: 0.8303
# Epoch 9/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.3954 - rounded_accuracy: 0.8363 - val_loss: 0.3907 - val_rounded_accuracy: 0.8414
# Epoch 10/10
# 1719/1719 [==============================] - 2s 1ms/step - loss: 0.3854 - rounded_accuracy: 0.8455 - val_loss: 0.3830 - val_rounded_accuracy: 0.8487

# %%
tf.random.set_seed(42)
np.random.seed(42)

noise = keras.layers.GaussianNoise(0.2)
show_reconstructions(denoising_ae, noise(X_valid, training=True))
plt.show()
# Out:
# 1/1 [==============================] - 0s 46ms/step

# %% [markdown]
# Using dropout

# %%
tf.random.set_seed(42)
np.random.seed(42)

dropout_encoder = keras.models.Sequential([
    keras.layers.Flatten(input_shape=[28, 28]),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(100, activation="selu"),
    keras.layers.Dense(30, activation="selu")
])
dropout_decoder = keras.models.Sequential([
    keras.layers.Dense(100, activation="selu", input_shape=[30]),
    keras.layers.Dense(28 * 28, activation="sigmoid"),
    keras.layers.Reshape([28, 28])
])
dropout_ae = keras.models.Sequential([dropout_encoder, dropout_decoder])
dropout_ae.compile(loss="binary_crossentropy", optimizer=keras.optimizers.SGD(lr=1.0),
                   metrics=[rounded_accuracy])
history = dropout_ae.fit(X_train, X_train, epochs=10,
                         validation_data=(X_valid, X_valid))
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/10
# 1719/1719 [==============================] - 3s 2ms/step - loss: 0.6740 - rounded_accuracy: 0.5757 - val_loss: 0.6166 - val_rounded_accuracy: 0.6675
# Epoch 2/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.5589 - rounded_accuracy: 0.7097 - val_loss: 0.5145 - val_rounded_accuracy: 0.7338
# Epoch 3/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.5031 - rounded_accuracy: 0.7389 - val_loss: 0.4966 - val_rounded_accuracy: 0.7423
# Epoch 4/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4914 - rounded_accuracy: 0.7480 - val_loss: 0.4873 - val_rounded_accuracy: 0.7544
# Epoch 5/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4809 - rounded_accuracy: 0.7616 - val_loss: 0.4743 - val_rounded_accuracy: 0.7716
# Epoch 6/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4647 - rounded_accuracy: 0.7807 - val_loss: 0.4535 - val_rounded_accuracy: 0.7938
# Epoch 7/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4415 - rounded_accuracy: 0.8029 - val_loss: 0.4277 - val_rounded_accuracy: 0.8158
# Epoch 8/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4177 - rounded_accuracy: 0.8214 - val_loss: 0.4062 - val_rounded_accuracy: 0.8314
# Epoch 9/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.4003 - rounded_accuracy: 0.8344 - val_loss: 0.3927 - val_rounded_accuracy: 0.8416
# Epoch 10/10
# 1719/1719 [==============================] - 3s 1ms/step - loss: 0.3900 - rounded_accuracy: 0.8423 - val_loss: 0.3851 - val_rounded_accuracy: 0.8475

# %%
tf.random.set_seed(42)
np.random.seed(42)

dropout = keras.layers.Dropout(0.5)
show_reconstructions(dropout_ae, dropout(X_valid, training=True))
# Out:
# 1/1 [==============================] - 0s 47ms/step
